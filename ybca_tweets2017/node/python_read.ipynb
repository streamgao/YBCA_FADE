# %%
# %matplotlib inline

from IPython.core.debugger import Tracer
import operator
import math
import datetime
import pytz
from pytz import country_timezones, timezone
import time
import sys
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib.patches as mpatches

import csv 
import pandas as pd 
import pandas.io.sql as sql
from pandasql import sqldf
import MySQLdb 
import networkx as nx
import IPython.display as display


import json
import gzip
from collections import Counter

# %%
data = pd.read_csv('data/2016-07-17/part-00000', header=None)
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-4-212b15b56933> in <module>()
# ----> 1 data = pd.read_csv('data/2016-07-17/part-00000', header=None)
#
# /Users/weidong/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     527                     skip_blank_lines=skip_blank_lines)
#     528
# --> 529         return _read(filepath_or_buffer, kwds)
#     530
#     531     parser_f.__name__ = name
#
# /Users/weidong/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     303         return parser
#     304
# --> 305     return parser.read()
#     306
#     307 _parser_defaults = {
#
# /Users/weidong/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#     761                 raise ValueError('skip_footer not supported for iteration')
#     762
# --> 763         ret = self._engine.read(nrows)
#     764
#     765         if self.options.get('as_recarray'):
#
# /Users/weidong/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#    1211     def read(self, nrows=None):
#    1212         try:
# -> 1213             data = self._reader.read(nrows)
#    1214         except StopIteration:
#    1215             if self._first_chunk:
#
# pandas/parser.pyx in pandas.parser.TextReader.read (pandas/parser.c:7988)()
#
# pandas/parser.pyx in pandas.parser.TextReader._read_low_memory (pandas/parser.c:8244)()
#
# pandas/parser.pyx in pandas.parser.TextReader._read_rows (pandas/parser.c:8970)()
#
# pandas/parser.pyx in pandas.parser.TextReader._tokenize_rows (pandas/parser.c:8838)()
#
# pandas/parser.pyx in pandas.parser.raise_parser_error (pandas/parser.c:22649)()
#
# CParserError: Error tokenizing data. C error: Expected 5 fields in line 47, saw 6

# %%
f=open('data/2016-07-17/test.txt', 'r')

# %%
for line in f:
    print line
# Out:
# [kimbyjag,#womancard,orlando, fl,2016-07-16T23:58:32.000Z]
#
# [dwarfen_king,,usa,2016-07-16T23:58:33.000Z]
#
# [cascoed51,,ft. myers beach, florida,2016-07-16T23:58:33.000Z]
#
# [777Francejacque,,new york, usa,2016-07-16T23:58:33.000Z]
#
# [JimmieAll7n5e,#republicans #gop #nevertrump #lovetrumpshate #imwithher #bernieorbust,nevada,2016-07-16T23:58:33.000Z]
#
# [dsoderstrom,,texas, usa,2016-07-16T23:58:33.000Z]
#
# [nodramahea,#gop #gopconvention,brooklyn, ny,2016-07-16T23:58:33.000Z]
#
# [pm4ra2r,#republicans #gop #nevertrump #lovetrumpshate #imwithher #bernieorbust,phoenix, arizona,2016-07-16T23:58:33.000Z]
#
# [hawgcaller,,rogers, arkansas,2016-07-16T23:58:33.000Z]
#
# [carmelinavicari,,new hampshire, usa,2016-07-16T23:58:33.000Z]
#
# [Order227blog,#abovethelaw,texas,2016-07-16T23:58:33.000Z]
#
# [KARENinFLA,,ellenton, fl,2016-07-16T23:58:33.000Z]
#
# [Mariablanca,,pa,2016-07-16T23:58:34.000Z]
#
# [eddiesurfs,#labour #kinnock #liberal #corbyn #nec,uk,2016-07-16T23:58:34.000Z]
#
# [BRAVESFAN92912,,florida, usa,2016-07-16T23:58:34.000Z]
#
# [BrAiNfReEzE69,#obamaslegacy #tcot,usa,2016-07-16T23:58:34.000Z]
#
# [galacticasitrep,#bernie #progessive #politics #yourvote2016,los angeles, ca,2016-07-16T23:58:35.000Z]
#
# [CathyTo47590555,#turkey #turkeycoupattempt #trump #israel #tcot,usa #trump2016 #imwithyou,2016-07-16T23:58:35.000Z]
#
# [Ilikecakealso,,canada,2016-07-16T23:58:35.000Z]
#
# [AgnesGoochy627,,hamden ct,2016-07-16T23:58:35.000Z]
#
# [DavidSherblom,,clinton, ma,2016-07-16T23:58:35.000Z]
#
# [kennyv777,#donaldtrump #nevertrump #tcot,usa,2016-07-16T23:58:36.000Z]
#
# [vetfortrump1,#trumppence16 #trump2016 #trump #makeamericagreatagain #maga #imwithyou #neverhillary,kansas, usa,2016-07-16T23:58:36.000Z]
#
# [David747Heavy,,northern new jersey, usa,2016-07-16T23:58:36.000Z]
#
# [rhysbart,,denver airport,2016-07-16T23:58:36.000Z]
#
# [tonyr951,#buildthewall,socal,2016-07-16T23:58:36.000Z]
#
# [EbonyPrincess2,#obamajama #uniteblue #tntweeters,united states,2016-07-16T23:58:37.000Z]
#
# [VictalPavO,#republicans #gop #nevertrump #lovetrumpshate #imwithher #bernieorbust,idaho,2016-07-16T23:58:37.000Z]
#
# [NUPEsupreme,#gop,los angeles, ca,2016-07-16T23:58:37.000Z]
#
# [bydefault,#trump #trumptrain #trump2016 #trumppence16 #indiana #ohio #gopconvention,twitty city,2016-07-16T23:58:37.000Z]
#
# [crazy4jp_amy,#makeamericagreatagain #trumppence #maga #isis #crooked #government,united states,2016-07-16T23:58:37.000Z]
#
# [ReneNowb,#gopconvention #gop #blacklivesmatter #trumppence #pbsnewshour,singing in the silence.,2016-07-16T23:58:37.000Z]
#
# [sujiai,,guam,2016-07-16T23:58:37.000Z]
#
# [art196048,,texas, usa,2016-07-16T23:58:38.000Z]
#
# [careerjett,#jobs #jobsearch #trump,new york, usa,2016-07-16T23:58:38.000Z]
#
# [AdamPiecoro,,30117,2016-07-16T23:58:38.000Z]
#
# [HorseShort,#makeamericagreatagain,texas, usa,2016-07-16T23:58:38.000Z]
#
# [DevilDogTrikes,,los angeles,2016-07-16T23:58:39.000Z]
#
# [TrumpBait,#hillary,from somewhere along the trail,2016-07-16T23:58:38.000Z]
#
# [CalikellyKelly,#trump2016 #hillary #trumppence #maga #americafirst #rednationrising #uniteblue #tcot,california, usa,2016-07-16T23:58:39.000Z]
#
# [BWSchank,#islam #tcot,islam=antichris  1jn2:22-23/2jn1:7,2016-07-16T23:58:39.000Z]
#
# [WatsinURWallet,,ohio, usa,2016-07-16T23:58:39.000Z]
#
# [CKscullycat,#bluewave2016 #votebluedownballot #imwithher,west coast, usa,2016-07-16T23:58:39.000Z]
#
# [NickyP2016,#mikepence,clinton county, hillary nation,2016-07-16T23:58:40.000Z]
#
# [LisaKravMama,#gunsense,the magnolia state,2016-07-16T23:58:40.000Z]
#
# [Don_Vito_08,#hillary,united states,2016-07-16T23:58:40.000Z]
#
# [shad39,#tcot,suffolk , lake ronkonkoma , ny,2016-07-16T23:58:40.000Z]
#
# [mdmiller99,#trump2016 #hillary #trumppence #maga #americafirst #rednationrising #uniteblue #tcot,united states,2016-07-16T23:58:40.000Z]
#
# [DebbieDeeWrigh2,#byebyebernie,santa barbara, ca,2016-07-16T23:58:40.000Z]
#
# [LainieYennie,#trump2016,new york, usa,2016-07-16T23:58:40.000Z]
#
# [jd_Constitution,#trump2016 #americafirst #usa,alabama, usa,2016-07-16T23:58:40.000Z]
#
# [PoliticalScott,,north carolina,2016-07-16T23:58:41.000Z]
#
# [DBHnBuckhead,,buckhead village, atlanta,2016-07-16T23:58:41.000Z]
#
# [sassysassyred,#potus #tcot #pjnet #p2,texas,2016-07-16T23:58:41.000Z]
#
# [17Kelly76,,near a shoreline,2016-07-16T23:58:41.000Z]
#
# [YodaLoco,#trump #currentevents,florida, usa,2016-07-16T23:58:41.000Z]
#
# [DaveGreco33,,new jersey, usa,2016-07-16T23:58:41.000Z]
#
# [BrandensteinKat,#trumppence16,kentucky, usa,2016-07-16T23:58:41.000Z]
#
# [FreedomChild3,#bcot #tcot #ccot #pjnet,where i am meant to be,2016-07-16T23:58:42.000Z]
#
# [rdbknighttempla,,the walls of acre,2016-07-16T23:58:42.000Z]
#
# [epc_nv,#makeamericagreatagain #trumppence16,las vegas, nv,2016-07-16T23:58:42.000Z]
#
# [michelle_rene,#imwithher,hampton roads, nova, maryland,2016-07-16T23:58:42.000Z]
#
# [Maggyw519,#freepurvi #trumppence,beautiful northwest usa,2016-07-16T23:58:42.000Z]
#
# [Zetrolly,#trump2016,southern oregon, usa,2016-07-16T23:58:42.000Z]
#
# [rhysbart,,denver airport,2016-07-16T23:58:43.000Z]
#
# [CAngielaMC,,saitama-ken, japan,2016-07-16T23:58:43.000Z]
#
# [aviv1818,#bernieorbusters #trumptrain #maga,usa,2016-07-16T23:58:43.000Z]
#
# [Sammasssie11,,grand old party,2016-07-16T23:58:43.000Z]
#
# [Mariablanca,,pa,2016-07-16T23:58:43.000Z]
#
# [Versailles56,,gettysburg, pennsylvania,2016-07-16T23:58:43.000Z]
#
# [fungrl1111,#trump2016,san diego, ca,2016-07-16T23:58:44.000Z]
#
# [clairydactyl,,earth,2016-07-16T23:58:44.000Z]
#
# [StopStopHillary,,united states,2016-07-16T23:58:44.000Z]
#
# [kessmom22,#bluelivesmatter #respecttheblue #lawandordercandidate,new jersey, usa,2016-07-16T23:58:45.000Z]
#
# [cof_real,,flint, mi,2016-07-16T23:58:45.000Z]
#
# [kokeshi_me,#neverhillary #hillaryforprison2016 #gogreen,tokyo, japan,2016-07-16T23:58:45.000Z]
#
# [ANCHORSEND1,#election2016,l.a.,2016-07-16T23:58:45.000Z]
#
# [wraithvenge,#hillary,classified,2016-07-16T23:58:45.000Z]
#
# [Ourob0,#trump,e tan e epi tas,2016-07-16T23:58:45.000Z]
#
# [Wind2Energy,,the interstices,2016-07-16T23:58:45.000Z]
#
# [Tristanaxl1e,#republicans #gop #nevertrump #lovetrumpshate #imwithher #bernieorbust,dallas, texas,2016-07-16T23:58:46.000Z]
#
# [DonniceHarrison,,vallejo, california, usa,2016-07-16T23:58:46.000Z]
#
# [JamesS020770,#trumppence16 #trumppence #trump,us / ca,2016-07-16T23:58:46.000Z]
#
# [david__co,,france-spain,2016-07-16T23:58:46.000Z]
#
# [SeeYouInPhilly1,#convention #stillsanders #seeyouinphilly #o,united states,2016-07-16T23:58:46.000Z]
#
# [VannagrammyLiz,,nmb sc,2016-07-16T23:58:46.000Z]
#
# [JACKSBACK100,,ellicott city, md,2016-07-16T23:58:47.000Z]
#
# [aubrym64,#trumptrain #maga,greater vancouver,2016-07-16T23:58:47.000Z]
#
# [eliawa29dr,#republicans #gop #nevertrump #lovetrumpshate #imwithher #bernieorbust,aspen, colorado,2016-07-16T23:58:47.000Z]
#
# [dwyer_barbara,#trumppence2016 #trumptrain,south boston, ma,2016-07-16T23:58:47.000Z]
#
# [SilvanaCorsetti,#tcot,illinois,2016-07-16T23:58:47.000Z]
#
# [carmelinavicari,#bernie,new hampshire, usa,2016-07-16T23:58:47.000Z]
#
# [RandalGerman,,alabama, usa,2016-07-16T23:58:48.000Z]
#
# [LionsOmega,#tcot,fema region 6,2016-07-16T23:58:48.000Z]
#
# [StCyrlyMe2,#donaldtrump #mikepence #amjoy,henderson nv,2016-07-16T23:58:48.000Z]
#
# [NormanFRusso,,the golden state,2016-07-16T23:58:48.000Z]
#
# [aertwitt,#repressiveregimes #womensrights,evansville, in,2016-07-16T23:58:48.000Z]
#
# [JamesEFinch,,united states,2016-07-16T23:58:48.000Z]
#
# [DawnMariefhl,#bluehand #francetruckattack #espys #trump2016,united states,2016-07-16T23:58:48.000Z]
#
# [3wombats,#trump,australia,2016-07-16T23:58:48.000Z]
